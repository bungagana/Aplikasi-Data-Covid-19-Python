# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('123.csv')
df
# Out:
#            date           state  fips    cases  deaths
# 0    2021-01-28         Alabama     1   452734    7340
# 1    2021-01-28          Alaska     2    53524     253
# 2    2021-01-28         Arizona     4   745976   12861
# 3    2021-01-28        Arkansas     5   290856    4784
# 4    2021-01-28      California     6  3272207   39521
# ..          ...             ...   ...      ...     ...
# 101  2021-01-27           Texas    48  2310785   36024
# 102  2021-01-27            Utah    49   340684    1620
# 103  2021-01-27         Vermont    50    11379     172
# 104  2021-01-27  Virgin Islands    78     2373      24
# 105  2021-01-27        Virginia    51   488553    6228
#
# [106 rows x 5 columns]

# %%
Washington = df[df['state'] == 'Washington']
Washington
# Out:
#           date       state  fips   cases  deaths
# 51  2021-01-28  Washington    53  312042    4328

# %%
texas = 'Texas'
get = df[df['state'] == texas]
get
# Out:
#            date  state  fips    cases  deaths
# 46   2021-01-28  Texas    48  2330107   36434
# 101  2021-01-27  Texas    48  2310785   36024

# %%
plt.plot(df.cases, df.deaths)
plt.show()

# %%
plt.plot(df.cases, df.deaths)
plt.show()

# %%
plt.plot(df.cases, df.date)
plt.show()

# %%
sorting = df[df.sort_values(by='cases', ascending=False)]
sorting
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-701bb6711037> in <module>
# ----> 1 sorting = df[df.sort_values(by='cases', ascending=False)]
#       2 sorting
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) DataFrame?
#    2892         if isinstance(key, DataFrame):
# -> 2893             return self.where(key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9009         other = com.apply_if_callable(other, self)
#    9010         return self._where(
# -> 9011             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9012         )
#    9013
#
# ...

# %%
sorting = df.sort_values(by='cases', ascending=False)
sorting
# Out:
#            date                     state  fips    cases  deaths
# 4    2021-01-28                California     6  3272207   39521
# 59   2021-01-27                California     6  3252716   38927
# 46   2021-01-28                     Texas    48  2330107   36434
# 101  2021-01-27                     Texas    48  2310785   36024
# 9    2021-01-28                   Florida    12  1687586   26034
# ..          ...                       ...   ...      ...     ...
# 66   2021-01-27                      Guam    66     8537     130
# 49   2021-01-28            Virgin Islands    78     2384      24
# 104  2021-01-27            Virgin Islands    78     2373      24
# 91   2021-01-27  Northern Mariana Islands    69      131       2
# 36   2021-01-28  Northern Mariana Islands    69      131       2
#
# [106 rows x 5 columns]

# %%
plt.plot(sorting.cases, sorting.date)
plt.show()

# %%
df.sort_values(by='cases', key=lambda col: ascending)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1064652d46d9> in <module>
# ----> 1 df.sort_values(by='cases', key=lambda col: ascending)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5306
#    5307             indexer = nargsort(
# -> 5308                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    5309             )
#    5310
#
# ~/.local/lib/python3.6/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position, key)
#     278
#     279     if key is not None:
# --> 280         items = ensure_key_mapped(items, key)
#     281         return nargsort(
#     282             items, kind=kind, ascending=ascending, na_position=na_position, key=None
#
# ...

# %%
dict1 = df.to_dict('dict')
dict1
# Out:
# {'date': {0: '2021-01-28',
#   1: '2021-01-28',
#   2: '2021-01-28',
#   3: '2021-01-28',
#   4: '2021-01-28',
#   5: '2021-01-28',
#   6: '2021-01-28',
#   7: '2021-01-28',
#   8: '2021-01-28',
#   9: '2021-01-28',
#   10: '2021-01-28',
#   11: '2021-01-28',
#   12: '2021-01-28',
#   13: '2021-01-28',
#   14: '2021-01-28',
#   15: '2021-01-28',
#   16: '2021-01-28',
#   17: '2021-01-28',
#   18: '2021-01-28',
#   19: '2021-01-28',
#   20: '2021-01-28',
#   21: '2021-01-28',
#   22: '2021-01-28',
#   23: '2021-01-28',
#   24: '2021-01-28',
#   25: '2021-01-28',
#   26: '2021-01-28',
#   27: '2021-01-28',
#   28: '2021-01-28',
#   29: '2021-01-28',
#   30: '2021-01-28',
#   31: '2021-01-28',
#   32: '2021-01-28',
#   33: '2021-01-28',
#   34: '2021-01-28',
#   35: '2021-01-28',
#   36: '2021-01-28',
#   37: '2021-01-28',
#   38: '2021-01-28',
#   39: '2021-01-28',
#   40: '2021-01-28',
#   41: '2021-01-28',
#   42: '2021-01-28',
#   43: '2021-01-28',
#   44: '2021-01-28',
# ...

# %%
df.filter(["state","cases"])
# Out:
#               state    cases
# 0           Alabama   452734
# 1            Alaska    53524
# 2           Arizona   745976
# 3          Arkansas   290856
# 4        California  3272207
# ..              ...      ...
# 101           Texas  2310785
# 102            Utah   340684
# 103         Vermont    11379
# 104  Virgin Islands     2373
# 105        Virginia   488553
#
# [106 rows x 2 columns]
